# %% [markdown]
# # The Spark Foundation -Data science and business Analytics
# Perform Exploratory Data Analysis on dataset "sampleSuperstore"
# Data set- https://bit.ly/3i4rbWl

# %%
import numpy as np
import pandas as pd 
import seaborn as sns
from matplotlib import pyplot as plt

# %%
df=pd.read_csv("F:\html\.vscode\\SampleSuperstore.csv")

# %%
df.head()
# Out:
#         Ship Mode    Segment        Country             City       State  \
# 0    Second Class   Consumer  United States        Henderson    Kentucky
# 1    Second Class   Consumer  United States        Henderson    Kentucky
# 2    Second Class  Corporate  United States      Los Angeles  California
# 3  Standard Class   Consumer  United States  Fort Lauderdale     Florida
# 4  Standard Class   Consumer  United States  Fort Lauderdale     Florida
#
#    Postal Code Region         Category Sub-Category     Sales  Quantity  \
# 0        42420  South        Furniture    Bookcases  261.9600         2
# 1        42420  South        Furniture       Chairs  731.9400         3
# 2        90036   West  Office Supplies       Labels   14.6200         2
# 3        33311  South        Furniture       Tables  957.5775         5
# 4        33311  South  Office Supplies      Storage   22.3680         2
#
#    Discount    Profit
# 0      0.00   41.9136
# 1      0.00  219.5820
# 2      0.00    6.8714
# ...

# %%
df.tail()
# Out:
#            Ship Mode   Segment        Country         City       State  \
# 9989    Second Class  Consumer  United States        Miami     Florida
# 9990  Standard Class  Consumer  United States   Costa Mesa  California
# 9991  Standard Class  Consumer  United States   Costa Mesa  California
# 9992  Standard Class  Consumer  United States   Costa Mesa  California
# 9993    Second Class  Consumer  United States  Westminster  California
#
#       Postal Code Region         Category Sub-Category    Sales  Quantity  \
# 9989        33180  South        Furniture  Furnishings   25.248         3
# 9990        92627   West        Furniture  Furnishings   91.960         2
# 9991        92627   West       Technology       Phones  258.576         2
# 9992        92627   West  Office Supplies        Paper   29.600         4
# 9993        92683   West  Office Supplies   Appliances  243.160         2
#
#       Discount   Profit
# 9989       0.2   4.1028
# 9990       0.0  15.6332
# ...

# %%
df.isnull().sum()
# Out:
# Ship Mode       0
# Segment         0
# Country         0
# City            0
# State           0
# Postal Code     0
# Region          0
# Category        0
# Sub-Category    0
# Sales           0
# Quantity        0
# Discount        0
# Profit          0
# dtype: int64

# %% [markdown]
# there are no null values

# %%
df.describe()
# Out:
#         Postal Code         Sales     Quantity     Discount       Profit
# count   9994.000000   9994.000000  9994.000000  9994.000000  9994.000000
# mean   55190.379428    229.858001     3.789574     0.156203    28.656896
# std    32063.693350    623.245101     2.225110     0.206452   234.260108
# min     1040.000000      0.444000     1.000000     0.000000 -6599.978000
# 25%    23223.000000     17.280000     2.000000     0.000000     1.728750
# 50%    56430.500000     54.490000     3.000000     0.200000     8.666500
# 75%    90008.000000    209.940000     5.000000     0.200000    29.364000
# max    99301.000000  22638.480000    14.000000     0.800000  8399.976000

# %%
df.duplicated().sum()
# Out:
# 17

# %%
df.drop_duplicates()
# Out:
#            Ship Mode    Segment        Country             City       State  \
# 0       Second Class   Consumer  United States        Henderson    Kentucky
# 1       Second Class   Consumer  United States        Henderson    Kentucky
# 2       Second Class  Corporate  United States      Los Angeles  California
# 3     Standard Class   Consumer  United States  Fort Lauderdale     Florida
# 4     Standard Class   Consumer  United States  Fort Lauderdale     Florida
# ...              ...        ...            ...              ...         ...
# 9989    Second Class   Consumer  United States            Miami     Florida
# 9990  Standard Class   Consumer  United States       Costa Mesa  California
# 9991  Standard Class   Consumer  United States       Costa Mesa  California
# 9992  Standard Class   Consumer  United States       Costa Mesa  California
# 9993    Second Class   Consumer  United States      Westminster  California
#
# ...

# %%
df.dtypes
# Out:
# Ship Mode        object
# Segment          object
# Country          object
# City             object
# State            object
# Postal Code       int64
# Region           object
# Category         object
# Sub-Category     object
# Sales           float64
# Quantity          int64
# Discount        float64
# Profit          float64
# dtype: object

# %%
sns.pairplot(df,hue='Category')

# %%
sns.pairplot(df,hue='Region')

# %%
sns.pairplot(df)

# %%
df.corr()
# Out:
#              Postal Code     Sales  Quantity  Discount    Profit
# Postal Code     1.000000 -0.023854  0.012761  0.058443 -0.029961
# Sales          -0.023854  1.000000  0.200795 -0.028190  0.479064
# Quantity        0.012761  0.200795  1.000000  0.008623  0.066253
# Discount        0.058443 -0.028190  0.008623  1.000000 -0.219487
# Profit         -0.029961  0.479064  0.066253 -0.219487  1.000000

# %% [markdown]
# corr() is the linear relationship between two variables , automaticaly categorical variables are excluded

# %%
';kljm,.sns.heatmap(df.corr())
# Out:
# <AxesSubplot:>

# %% [markdown]
# For above heatmap results are:
# 1. Discount and Profit is Negative correlated.
# 2. Quantity and Profit are less Moderately correlated.
# 3. Sales and Profit are Moderately correlated.

# %% [markdown]
# # categorical data Analysis

# %%
a=df["Category"].value_counts()
b=[0,0.1,0.2]
plt.pie(a,labels=a.index,autopct='%.2f%%',explode=b)
plt.title("Category")
# Out:
# Text(0.5, 1.0, 'Category')

# %% [markdown]
# office supply is more than 50%

# %%
c=df["Region"].value_counts()
d=[0,0.1,0.2,0.2]
plt.pie(c,labels=c.index,autopct='%.2f%%',explode=d)
plt.title("Region")
# Out:
# Text(0.5, 1.0, 'Region')

# %%
f=df["Segment"].value_counts()
e=[0,0.1,0.2]
plt.pie(f,labels=f.index,autopct='%.2f%%',explode=e)
plt.title("Segment")
# Out:
# Text(0.5, 1.0, 'Segment')

# %%
g=df["Ship Mode"].value_counts()
d=[0,0.1,0.2,0.2]
plt.pie(g,labels=g.index,autopct='%.2f%%',explode=d)
plt.title("Ship Mode")
# Out:
# Text(0.5, 1.0, 'Ship Mode')

# %% [markdown]
# # Segment-wise analysis of Profit, Sale & Discount

# %%
df.groupby(["Segment"])[['Sales', 'Discount', 'Profit']].mean()
# Out:
#                   Sales  Discount     Profit
# Segment
# Consumer     223.733644  0.158141  25.836873
# Corporate    233.823300  0.158228  30.456667
# Home Office  240.972041  0.147128  33.818664

# %% [markdown]
# # Region-wise analysis of Profit, Sale & Discount

# %%
df.groupby(["Region"])[['Sales', 'Discount', 'Profit']].mean()
# Out:
#               Sales  Discount     Profit
# Region
# Central  215.772661  0.240353  17.092709
# East     238.336110  0.145365  32.135808
# South    241.803645  0.147253  28.857673
# West     226.493233  0.109335  33.849032

# %% [markdown]
# # Category-wise analysis of Profit, Sale & Discount

# %%
df.groupby(["Category"])[['Sales', 'Discount', 'Profit']].mean()
# Out:
#                       Sales  Discount     Profit
# Category
# Furniture        349.834887  0.173923   8.699327
# Office Supplies  119.324101  0.157285  20.327050
# Technology       452.709276  0.132323  78.752002

# %% [markdown]
# # Ship Mode-wise analysis of Profit, Sale & Discount

# %%
df.groupby(["Ship Mode"])[['Sales', 'Discount', 'Profit']].mean()
# Out:
#                      Sales  Discount     Profit
# Ship Mode
# First Class     228.497024  0.164610  31.839948
# Same Day        236.396179  0.152394  29.266591
# Second Class    236.089239  0.138895  29.535545
# Standard Class  227.583067  0.160023  27.494770

# %% [markdown]
# # Region wise ordered quantity

# %%
plt.figure(figsize=(10,10))
sns.countplot(x=df["Quantity"],hue=df["Region"])
plt.title('Region-wise ordered Quantity')
plt.show()

# %% [markdown]
# # Region-wise ordered product categories

# %%
plt.figure(figsize=(10,10))
sns.countplot(x=df["Region"],hue=df["Category"])
plt.title('Region-wise ordered Quantity')
plt.show()

# %% [markdown]
# Result-
# west region is orderd more all kind of products and south region is our least buyer.

# %% [markdown]
# # SubsCategory analysis

# %%
plt.figure(figsize=(15,10))
sns.countplot(x=df["Sub-Category"])
plt.title('sub-category counts')
plt.show()

# %%
sub_category_sales=df.groupby("Sub-Category").Sales.sum()
sub_category_sales
# Out:
# Sub-Category
# Accessories    167380.3180
# Appliances     107532.1610
# Art             27118.7920
# Binders        203412.7330
# Bookcases      114879.9963
# Chairs         328449.1030
# Copiers        149528.0300
# Envelopes       16476.4020
# Fasteners        3024.2800
# Furnishings     91705.1640
# Labels          12486.3120
# Machines       189238.6310
# Paper           78479.2060
# Phones         330007.0540
# Storage        223843.6080
# Supplies        46673.5380
# Tables         206965.5320
# Name: Sales, dtype: float64

# %%
sub_category_profit=df.groupby("Sub-Category").Profit.sum()
sub_category_profit
# Out:
# Sub-Category
# Accessories    41936.6357
# Appliances     18138.0054
# Art             6527.7870
# Binders        30221.7633
# Bookcases      -3472.5560
# Chairs         26590.1663
# Copiers        55617.8249
# Envelopes       6964.1767
# Fasteners        949.5182
# Furnishings    13059.1436
# Labels          5546.2540
# Machines        3384.7569
# Paper          34053.5693
# Phones         44515.7306
# Storage        21278.8264
# Supplies       -1189.0995
# Tables        -17725.4811
# Name: Profit, dtype: float64

# %%
plt.style.use("seaborn")
sub_category_sales.plot(kind = 'bar',figsize = (10,5),fontsize = 14,color = 'black')
sub_category_profit.plot(kind = 'bar',figsize = (10,5),fontsize = 14,color = 'r')
plt.xlabel("sub-category")
plt.ylabel("sales/profit")
plt.title("sales vs profit")
plt.legend()
plt.show()

# %%
sub_category_profit.plot.barh()
# Out:
# <AxesSubplot:ylabel='Sub-Category'>

# %% [markdown]
# The above graph clearly shows that Copiers and Phones have the highest sales and profit and tables has negative profit

# %%
fig,axes = plt.subplots(2,2,figsize=(14,12))
fig.suptitle("Distribution plots", fontsize=16)
sns.distplot(df['Sales'],ax=axes[0,0])
sns.distplot(df['Profit'],ax=axes[0,1])
sns.distplot(df['Discount'],ax=axes[1,0])
sns.distplot(df['Quantity'],ax=axes[1,1])
axes[0][0].set_title('Sales Distribution')
axes[0][1].set_title('Profit Distribution')
axes[1][0].set_title('Discount Distribution')
axes[1][1].set_title('Quantity Distribution')
plt.show()
# Out:
# c:\users\somesh sangwan\appdata\local\programs\python\python39\lib\site-packages\seaborn\distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# c:\users\somesh sangwan\appdata\local\programs\python\python39\lib\site-packages\seaborn\distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# ...

# %% [markdown]
# In the above graph, Sales distribution is rightly skewed and profit distribution is seems normal skewed.

# %% [markdown]
# # State - Wise analysis of Profit, Sales & Discount

# %%
df.groupby(['State'])[['Sales', 'Discount', 'Profit']].mean()
# Out:
#                             Sales  Discount      Profit
# State
# Alabama                319.846557  0.000000   94.865989
# Arizona                157.508933  0.303571  -15.303235
# Arkansas               194.635500  0.000000   66.811452
# California             228.729451  0.072764   38.171608
# Colorado               176.418231  0.316484  -35.867351
# Connecticut            163.223866  0.007317   42.823071
# Delaware               285.948635  0.006250  103.930988
# District of Columbia   286.502000  0.000000  105.958930
# Florida                233.612815  0.299347   -8.875461
# Georgia                266.825217  0.000000   88.315453
# Idaho                  208.689810  0.085714   39.367767
# Illinois               162.939230  0.390041  -25.625787
# Indiana                359.431946  0.000000  123.375411
# Iowa                   152.658667  0.000000   39.460397
# Kansas                 121.429583  0.000000   34.851813
# Kentucky               263.250000  0.000000   80.573357
# ...

# %%
a=df['State'].value_counts()
a.head()
# Out:
# California      2001
# New York        1128
# Texas            985
# Pennsylvania     587
# Washington       506
# Name: State, dtype: int64

# %%
a.plot(kind='bar',figsize=(12,6))
plt.ylabel('Number of Deals')
plt.xlabel('States')
plt.title('states-wise Dealings')
# Out:
# Text(0.5, 1.0, 'states-wise Dealings')

# %%
state_sales=df.groupby("State").Sales.sum()

# %%
state_sales
# Out:
# State
# Alabama                  19510.6400
# Arizona                  35282.0010
# Arkansas                 11678.1300
# California              457687.6315
# Colorado                 32108.1180
# Connecticut              13384.3570
# Delaware                 27451.0690
# District of Columbia      2865.0200
# Florida                  89473.7080
# Georgia                  49095.8400
# Idaho                     4382.4860
# Illinois                 80166.1010
# Indiana                  53555.3600
# Iowa                      4579.7600
# Kansas                    2914.3100
# Kentucky                 36591.7500
# Louisiana                 9217.0300
# Maine                     1270.5300
# Maryland                 23705.5230
# Massachusetts            28634.4340
# Michigan                 76269.6140
# Minnesota                29863.1500
# Mississippi              10771.3400
# Missouri                 22205.1500
# Montana                   5589.3520
# Nebraska                  7464.9300
# ...

# %%
state_profit=df.groupby("State").Profit.sum()

# %%
state_profit
# Out:
# State
# Alabama                  5786.8253
# Arizona                 -3427.9246
# Arkansas                 4008.6871
# California              76381.3871
# Colorado                -6527.8579
# Connecticut              3511.4918
# Delaware                 9977.3748
# District of Columbia     1059.5893
# Florida                 -3399.3017
# Georgia                 16250.0433
# Idaho                     826.7231
# Illinois               -12607.8870
# Indiana                 18382.9363
# Iowa                     1183.8119
# Kansas                    836.4435
# Kentucky                11199.6966
# Louisiana                2196.1023
# Maine                     454.4862
# Maryland                 7031.1788
# Massachusetts            6785.5016
# Michigan                24463.1876
# Minnesota               10823.1874
# Mississippi              3172.9762
# Missouri                 6436.2105
# Montana                  1833.3285
# Nebraska                 2037.0942
# ...

# %%
state_sales.plot(kind='bar',color='r',figsize=(12,6))
state_profit.plot(kind='bar',color='b',figsize=(12,6))
plt.title("state-sales vs profit")
plt.legend()
plt.show()

# %% [markdown]
# # -----------------------------------THANKS-----------------------------------

# %% [markdown]
# # conclusion

# %% [markdown]
# 1. Weak Areas -

# %% [raw]
# i) We should limit sales of furniture and increase that of technology and office suppliers as furniture has very less profit as compared to sales.
# ii) Increase sales more in the east as profit is more.
# iii) Need to give some discount and other offer in state (colorado, texas, north carolina,ohio) because there is sale is fine but no profit.

# %% [markdown]
# 2.Others-

# %% [raw]
# 1)The feature Profit and Discount are highly related
# 2)The mode of shipping does not affect sales
# 3)The home office provides highly sales followed by corporate by a slight variation.
# 4)Over Less quantity of products also the sales were high
